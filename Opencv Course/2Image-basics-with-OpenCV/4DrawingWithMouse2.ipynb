# %%
import cv2
import numpy as np


#Function

def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:#Left
        cv2.circle(img,(x,y),100,(0,255,0),-1)
    elif event == cv2.EVENT_RBUTTONDOWN:#Right
        cv2.circle(img,(x,y),100,(255,0,0),-1)


cv2.namedWindow(winname="my_drawing")
cv2.setMouseCallback("my_drawing",draw_circle) #callback funct -> draw_circle




#showing image with OpenCV

img = np.zeros((1080,1080,3),np.int8)

while True:
    cv2.imshow("my_drawing",img)

    if cv2.waitKey(20) & 0xFF ==27:
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      24 while True:
#      25     cv2.imshow("my_drawing",img)
# ---> 27     if cv2.waitKey(20) & 0xFF ==27:
#      28         break
#      30 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %% [markdown]
# ![image.png](attachment:image.png)
